# %% [markdown]
# # Imports

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# general array and data handling
import numpy as np
import pandas as pd

# tensor operations and neural networks
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LeakyReLU

# Ploting
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # Data Loading

# %%
# !git clone https://github.com/grudloff/stock_market_GAN.git
# Out:
# fatal: destination path 'stock_market_GAN' already exists and is not an empty directory.

# %%
data_names = ["S&P500","SSE","IBM","MSFT","PAICC"]
data_name = data_names[0]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path)
# Out:
# stock_market_GAN/datasets/S&P500.csv

# %%
dataframe.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  5031.000000  5031.000000  ...  5031.000000  5.031000e+03
# mean   1495.419580  1504.207347  ...  1495.566086  2.954812e+09
# std     499.462791   499.894439  ...   499.378368  1.545804e+09
# min     679.280029   695.270020  ...   676.530029  3.121200e+08
# 25%    1151.739990  1159.934998  ...  1151.629944  1.488865e+09
# 50%    1334.369995  1343.319946  ...  1334.219971  3.078530e+09
# 75%    1806.269959  1810.450012  ...  1805.450012  3.886925e+09
# max    2936.760010  2940.909912  ...  2930.750000  1.145623e+10
#
# [8 rows x 6 columns]

# %%
dataframe.shape
# Out:
# (5031, 7)

# %%
def add_Ma(dataframe):
  Ma_window=5
  for i in range(0,dataframe.shape[0]-Ma_window):
    dataframe.loc[dataframe.index[i+Ma_window],'Ma'] = np.round(((dataframe.iloc[i,4]+ dataframe.iloc[i+1,4] +dataframe.iloc[i+2,4] + dataframe.iloc[i+3,4]+ dataframe.iloc[i+4,4])/5),6)
  return dataframe[5:-5]

dataframe=add_Ma(dataframe)
dataframe.head()
# Out:
#          Date         Open         High  ...    Adj Close     Volume           Ma
# 5  1999-01-11  1275.089966  1276.219971  ...  1263.880005  818000000  1258.007983
# 6  1999-01-12  1263.880005  1264.449951  ...  1239.510010  800200000  1265.163989
# 7  1999-01-13  1239.510010  1247.750000  ...  1234.400024  931500000  1264.109985
# 8  1999-01-14  1234.400024  1236.810059  ...  1212.189941  797200000  1256.521997
# 9  1999-01-15  1212.189941  1243.260010  ...  1243.260010  798100000  1245.013989
#
# [5 rows x 8 columns]

# %%
def plot_dataframe(dataframe):

  for column_name in dataframe.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(dataframe[column_name])

plot_dataframe(dataframe)

# %% [markdown]
# # Preprocessing

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    # shape : (n_batch, n_sequence, n_features)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    std[std==0] = 1
    samples = (samples - mean[:,None,:])/std[:,None,:] #standarize along each feature
    targets = (targets - mean[:,3:4])/std[:,3:4] # The close value is our target
    return samples, targets

# %%
# TimeseriesGenerator Check

data = np.array([[i, i**2,i**3,i**4] for i in range(11)])
targets = np.array([[i**4] for i in range(11)])

print(targets.shape)

mean = data[:-1].mean(axis=0)[None,:]
std = data[:-1].std(axis=0)[None,:]

data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=10, sampling_rate=1,
                               batch_size=2)
batch_0 = data_gen[0]
x, y = batch_0

print(np.array(x*std+mean,dtype = np.int))
print(y*std[..., 3]+mean[..., 3])
# Out:
# (11, 1)
# [[[   0    0    0    0]
#   [   1    1    1    1]
#   [   2    4    8   16]
#   [   3    9   27   81]
#   [   4   16   64  256]
#   [   5   25  125  625]
#   [   6   36  216 1296]
#   [   7   49  343 2401]
#   [   8   64  512 4096]
#   [   9   81  729 6561]]]
# [[10000.]]

# %%
data.shape
# Out:
# (11, 4)

# %%
# Generarate 5 days sequences from all data
# TODO: How to deal with weekend lack of information?

n_sequence = 5
n_batch = 128
n_features = 7

def get_gen_train_test(dataframe):
  data = dataframe.drop(columns='Date').to_numpy()
  targets = data[:,3, None] #add none to have same number of dimensions as data
  #targets = data
  n_samples = data.shape[0]

  train_test_split=int(n_samples*0.9)

  data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
  data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)
  
  return data_gen_train, data_gen_test

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

# %%
data_gen_train[0]
# Out:
# (array([[[ 5.45971947e-01,  1.27735988e+00,  1.56175563e+00, ...,
#            1.79051479e+00,  4.16271825e-01, -1.10866930e+00],
#          [ 1.50603133e+00,  1.08913257e+00,  8.04803492e-01, ...,
#            2.85494182e-01,  2.16926900e-01,  7.66904120e-01],
#          [-4.86785873e-02, -5.52134937e-01, -9.64240389e-01, ...,
#           -1.07493403e+00,  1.50383983e+00,  1.41892745e+00],
#          [-1.46250925e+00, -1.24728345e+00, -7.11215829e-01, ...,
#           -3.33218659e-01, -7.25985073e-01,  4.19692678e-03],
#          [-5.40815442e-01, -5.67074055e-01, -6.91102900e-01, ...,
#           -6.67856283e-01, -1.41105348e+00, -1.08135920e+00]],
#
#         [[-1.24337916e+00, -1.10635268e+00, -9.78012327e-01, ...,
#           -1.36448568e+00, -7.14254424e-01, -1.20715234e+00],
#          [-6.95600914e-01, -1.00039368e+00, -1.27545255e+00, ...,
#           -8.43447391e-01, -1.76966355e-01, -8.10687337e-01],
#          [-2.27606867e-01, -2.25823055e-01,  5.71280431e-02, ...,
#            1.13155259e-02, -4.20141221e-01, -1.00635496e-01],
#          [ 5.48834276e-01,  1.20964436e+00,  1.12556680e+00, ...,
#            1.18222229e+00,  1.96376543e+00,  4.97333130e-01],
#          [ 1.61775266e+00,  1.12292506e+00,  1.07077003e+00, ...,
#            1.01439525e+00, -6.52403426e-01,  1.62114204e+00]],
#
#         [[ 8.58883969e-01,  9.24586717e-01,  1.67591108e+00, ...,
#            1.67545172e+00,  5.37639645e-01,  1.07272948e+00],
#          [ 1.25183862e+00,  8.99420399e-01, -5.66260281e-01, ...,
#           -6.57956185e-01, -5.64548808e-01,  1.01371811e+00],
#          [-8.73785595e-01, -9.42916223e-01,  5.24584114e-01, ...,
#            4.60756212e-01, -1.61373436e+00,  7.38789985e-02],
#          [ 1.45308481e-01,  5.74080288e-01, -4.56478440e-01, ...,
#           -1.21611896e+00,  3.50090931e-01, -5.88908036e-01],
#          [-1.38224548e+00, -1.45517118e+00, -1.17775647e+00, ...,
#           -2.62132783e-01,  1.29055260e+00, -1.57141855e+00]],
#
#         ...,
#
#         [[-4.99361411e-01,  6.19218203e-01,  1.37353143e-01, ...,
#            6.84314077e-01, -1.52192051e+00, -1.60583791e+00],
#          [ 1.23618424e+00,  1.25786350e+00,  1.88397181e+00, ...,
#            3.25108981e-01, -5.47485324e-01, -6.24558007e-01],
#          [ 8.47044676e-01, -9.40496830e-01, -7.79501995e-01, ...,
#           -3.66773608e-01,  2.87064274e-01,  2.94518427e-01],
#          [-1.14810051e-03, -1.39328388e+00, -7.83851405e-01, ...,
#           -1.75048468e+00,  1.48834797e+00,  1.15590149e+00],
#          [-1.58271940e+00,  4.56699001e-01, -4.57971554e-01, ...,
#            1.10783523e+00,  2.93993591e-01,  7.79975997e-01]],
#
#         [[-1.72691364e+00, -1.60062550e+00, -1.46321928e+00, ...,
#           -6.58006175e-01, -1.57234819e+00, -1.62339065e+00],
#          [ 2.08221001e-01,  1.02908144e+00,  1.12907711e-01, ...,
#           -1.26508440e+00, -1.19025444e-01, -5.69193161e-01],
#          [-3.76463706e-01, -7.29661426e-01, -3.34116776e-01, ...,
#            2.50662620e-01,  7.88885864e-01,  2.19199457e-01],
#          [ 1.08337140e+00,  6.47796521e-01,  3.10552009e-02, ...,
#           -3.13256355e-02,  1.31262972e+00,  8.35943008e-01],
#          [ 8.11784946e-01,  6.53408965e-01,  1.65337314e+00, ...,
#            1.70375359e+00, -4.10141955e-01,  1.13744135e+00]],
#
#         [[ 1.67508814e-01, -2.23899339e-01,  1.32383330e-01, ...,
#           -1.03607443e+00, -3.62511774e-01,  1.68978270e+00],
#          [-1.68917816e+00, -9.31459445e-01, -1.60796602e+00, ...,
#           -8.52629566e-02, -2.25116737e-01,  5.35166827e-01],
#          [ 2.66596016e-01, -1.09810764e+00, -4.91024081e-01, ...,
#           -1.07709989e+00,  1.95246964e+00, -3.73830088e-01],
#          [-1.66169818e-01,  1.53743780e+00,  6.50103603e-01, ...,
#            6.85351155e-01, -4.89580807e-01, -9.76355180e-01],
#          [ 1.42124315e+00,  7.16028624e-01,  1.31650317e+00, ...,
#            1.51308612e+00, -8.75260318e-01, -8.74764261e-01]]]),
#  array([[-1.24338939],
#         [ 0.5284707 ],
#         [-0.64373595],
#         [-3.45262591],
#         [ 2.78654125],
#         [-0.03978078],
#         [-2.00053251],
#         [ 0.32219287],
#         [-0.14516537],
#         [ 2.88697677],
#         [ 3.17723479],
#         [-1.27985622],
#         [-2.3205052 ],
#         [ 1.01449932],
#         [-1.2199941 ],
#         [ 1.401511  ],
#         [-1.1883537 ],
#         [-0.18003577],
#         [-0.58873864],
#         [ 1.08632841],
#         [ 0.41322326],
#         [-3.21153023],
#         [-0.21690739],
#         [ 1.69569532],
#         [-0.65606242],
#         [ 0.74112629],
#         [-2.15399694],
#         [-0.93551401],
#         [-1.12734794],
#         [ 1.36940387],
#         [-1.29069332],
#         [ 1.05505417],
#         [ 0.80960795],
#         [ 1.20721483],
#         [ 1.66867571],
#         [ 1.33721276],
#         [ 2.48191968],
#         [ 0.37245585],
#         [ 1.60901124],
#         [ 0.42333477],
#         [ 1.33280854],
#         [ 0.28021752],
#         [-1.71183793],
#         [ 3.98933451],
#         [-2.07399838],
#         [-0.02331063],
#         [-0.60135987],
#         [ 3.2089065 ],
#         [-2.44316074],
#         [ 1.46897953],
#         [-1.36973066],
#         [ 0.53229334],
#         [ 1.74957542],
#         [ 0.47714134],
#         [ 1.79567165],
#         [ 1.07898464],
#         [-1.96499857],
#         [ 3.69559978],
#         [ 0.29829213],
#         [ 1.34462636],
#         [-2.16758185],
#         [ 1.63761373],
#         [-1.0472568 ],
#         [ 0.05911977],
#         [-6.15450347],
#         [-1.85923277],
#         [-6.44042291],
#         [ 1.79769417],
#         [ 2.12368542],
#         [ 1.29027456],
#         [ 0.81543872],
#         [ 1.91317093],
#         [-1.26441224],
#         [ 3.75545624],
#         [-1.16196816],
#         [ 3.46734333],
#         [ 1.34727713],
#         [-0.08684402],
#         [ 2.34613606],
#         [-2.0847682 ],
#         [-1.66252345],
#         [-0.76754976],
#         [ 1.37560334],
#         [-1.63535599],
#         [ 0.44962534],
#         [-7.77838538],
#         [-0.14516537],
#         [-0.0897673 ],
#         [-0.55817861],
#         [ 0.2932861 ],
#         [-1.83310446],
#         [ 0.31257279],
#         [-2.30707777],
#         [-1.08723566],
#         [ 0.7731435 ],
#         [-0.92482947],
#         [ 2.488088  ],
#         [-0.17548638],
#         [-6.47098164],
#         [-2.79126857],
#         [ 1.33280854],
#         [-0.97275118],
#         [ 0.05647384],
#         [-0.2946598 ],
#         [ 5.72343275],
#         [ 2.41883174],
#         [ 2.02467264],
#         [ 2.28017082],
#         [-2.25039805],
#         [-1.70502907],
#         [-0.2674013 ],
#         [-1.66064144],
#         [ 3.48526989],
#         [-0.38498666],
#         [ 2.63138148],
#         [-0.92459196],
#         [ 1.31854063],
#         [ 6.55559152],
#         [ 1.57115534],
#         [ 1.96836765],
#         [ 1.93826175],
#         [ 2.06400642],
#         [ 9.86175349],
#         [-0.01248101],
#         [-0.2632181 ],
#         [-1.02314178],
#         [ 0.88516043],
#         [ 1.00765345]]))

# %%
# test on data

x_gen, y_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=1)[0]
print(x_gen)
print(y_gen)

x = data[None, :5,:]
mean = x.mean(axis=1)
std = x.std(axis=1)
x = (x - mean)/std
y = (data[5,3] - mean[...,3])/std[...,3]
print(x)
print(y)

assert (x_gen == x).all()
assert y_gen == y
# Out:
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# [[5.69853465]]
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# [5.69853465]

# %% [markdown]
# # Baseline

# %%
# baseline: use previous day as estimation for the next
squared_error = 0
def mean_squared_error(X, lenght = 5):
  squared_error = 0
  for i in range(0, X.shape[0] - lenght):
    x = X[i:i+lenght]
    mean = x.mean()
    std = x.std()
    x = (x - mean)/std
    y = (X[i+lenght] - mean)/std
    squared_error += np.square(x[-1]-y)
  return squared_error/X.shape[0]

baseline_error = mean_squared_error(data[:,3])
baseline_error
# Out:
# 3.4528189810500125

# %%
data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=32)

# baseline: use previous day as estimation for the next
def mean_squared_error(dataset):
  mse=0
  for X_batch, y_batch in dataset:
    # X_batch.shape : (n_batch, n_sequence, n_features)
    #mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
    mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
  mse /= len(dataset)
  return mse

baseline_error = mean_squared_error(data_gen)
baseline_error
# Out:
# 6.330168131925023

# %% [markdown]
# # Utilities

# %%
# Metrics not included in keras

# For some reason keras mape is different so it has to be customly defined.
# Paper definition isn't percentual, hence the difference. (x100)
def mse(y_true, y_pred):
  return tf.reduce_mean(tf.square(y_true-y_pred))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)/y_true))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true-y_pred)))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:] > y_true[:-1],tf.float32)
    return tf.reduce_mean((y_true[1:]-y_true[:-1])*mask)


#class ar(tf.keras.metrics.Metric):
#  def __init__(self, name="ar", **kwargs):
#    super(ar, self).__init__(name=name, **kwargs)
#    self.y_old = self.add_weight(name='y_old', shape=n_batch, initializer='zeros', dtype=tf.float32)
#    self.y_true = self.add_weight(name='y_true', shape=n_batch, initializer='zeros', dtype=tf.float32)
#    self.y_pred = self.add_weight(name='y_pred', shape=n_batch, initializer='zeros', dtype=tf.float32)

#  def update_state(self, y_true, y_pred, sample_weight = None):
#    self.y_true = y_true[:,3]
#    self.y_pred = y_pred[:,3]
#    # shape y : (batch_size, n_features)
#    self.y_old = tf.stack([self.y_old[-1] , self.y_true[:-1]], 0)

#  def result(self):
#    mask = tf.cast(self.y_pred > self.y_old, tf.float32)
#    return tf.reduce_mean((self.y_true - self.y_old)*mask)

# %%
# Metrics not included in keras

# For some reason keras mape is different so it has to be customly defined.
# Paper definition isn't percentual, hence the difference. (x100)
#def mape(y_true, y_pred):
#    return tf.keras.backend.mean(tf.keras.backend.abs((y_true-y_pred)/y_true))
#    # ***The absolute is over the whole thing as y_true can be negative

#def rmse(y_true, y_pred):
#    return tf.sqrt(tf.keras.backend.mean(tf.square(y_true-y_pred)))

#def ar(y_true, y_pred):
#    N = tf.cast(tf.size(y_true), tf.float32)
#    return tf.keras.backend.sum(tf.keras.backend.maximum(y_true-y_pred, 0)) / (N-1)

# %% [markdown]
# # LSTM

# %%
def make_LSTM_model():

  inputs = Input(shape=(n_sequence, n_features,))

  lstm_1 = LSTM(units=10, return_sequences = True, activation=None, kernel_initializer='random_normal')(inputs)
  batch_norm1=tf.keras.layers.BatchNormalization()(lstm_1)
  lstm_1_LRelu = LeakyReLU(alpha=0.3)(batch_norm1) 
  lstm_1_droput = Dropout(0.3)(lstm_1_LRelu)
  lstm_2 = LSTM(units=10, return_sequences = False, activation=None, kernel_initializer='random_normal')(lstm_1_droput)
  batch_norm2=tf.keras.layers.BatchNormalization()(lstm_2)
  lstm_2_LRelu = LeakyReLU(alpha=0.3)(batch_norm2) 
  lstm_2_droput = Dropout(0.3)(lstm_2_LRelu)
  #lstm_3 = LSTM(units=10, return_sequences = True, activation=None)(lstm_2_droput)
  #batch_norm3=tf.keras.layers.BatchNormalization()(lstm_3)
  #lstm_3_LRelu = LeakyReLU(alpha=0.3)(batch_norm3) 
  #lstm_3_droput = Dropout(0.3)(lstm_3_LRelu)
  #lstm_4 = LSTM(units=100, return_sequences = False, activation=None)(lstm_3_droput)
  #batch_norm4=tf.keras.layers.BatchNormalization()(lstm_4)
  #lstm_4_LRelu = LeakyReLU(alpha=0.3)(batch_norm4) 
  #lstm_4_droput = Dropout(0.5)(lstm_4_LRelu)
  output_dense = Dense(1, activation=None)(lstm_2_droput)
  output = LeakyReLU(alpha=0.3)(output_dense) 


  model = Model(inputs = inputs, outputs = output)
  #model.compile(loss=generator_loss)
  model.compile(loss='mse', metrics = [mse , mae, mape, rmse, ar])
  #model.compile(loss=None, metrics = [mse , mae, mape, rmse])
  model.summary()

  #return model, slice_model
  return model

  #history = model.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
   #                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))

# %%
#lstm = make_LSTM_model()
#history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
#                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))

# %% [markdown]
# # Visualization

# %%
metrics = ["loss", 'mse','mae','mape','rmse','ar']
def plot_history(history):
  #metrics = ["loss", 'mse','mae','mape','rmse','ar']
  #metrics = ["gen_loss","gen_slice_loss", 'mse','mae','mape','rmae','ar']
  for metric_name in metrics:  
    plt.figure()
    plt.title(metric_name)
    plt.plot(history.history[metric_name], label='train')
    plt.plot(history.history["val_"+metric_name], label='test')
    plt.legend()
  plt.show()

#plot_history(history)

# %%
def plot_frame(sequence, target, model):
  sequence, target = data_gen_test[0]
  y_pred = model.predict(sequence)
  y_true = target

  plt.figure()
  plt.title("closing price")
  plt.plot(y_true, label="true")
  plt.plot(y_pred, label="prediction")
  plt.legend()
  plt.show()

#plot_frame(*data_gen_test[0], lstm)

# %% [markdown]
# # Test on all datasets

# %%
results = np.zeros((5,6))

# %% [markdown]
# ## S&P500

# %%
data_name = data_names[0]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

lstm = make_LSTM_model()
history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100,
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], lstm)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[0] = lstm.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/S&P500.csv
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 5, 10)             720
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 10)             40
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 5, 10)             0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 10)             0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 10)                840
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 10)                40
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 10)                0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 1,651
# Trainable params: 1,611
# Non-trainable params: 40
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 18ms/step - loss: 4.5120 - mse: 4.5120 - mae: 1.5056 - mape: 1.8553 - rmse: 2.1104 - ar: 0.8626 - val_loss: 5.1848 - val_mse: 5.1848 - val_mae: 1.6842 - val_mape: 0.9992 - val_rmse: 2.2695 - val_ar: 0.3168
# Epoch 2/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7128 - mse: 3.7128 - mae: 1.3507 - mape: 3.1521 - rmse: 1.9193 - ar: 0.8725 - val_loss: 5.1844 - val_mse: 5.1844 - val_mae: 1.6844 - val_mape: 1.0017 - val_rmse: 2.2694 - val_ar: 0.3152
# Epoch 3/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7182 - mse: 3.7182 - mae: 1.3267 - mape: 3.9258 - rmse: 1.9142 - ar: 0.8528 - val_loss: 5.1955 - val_mse: 5.1955 - val_mae: 1.6879 - val_mape: 1.0146 - val_rmse: 2.2717 - val_ar: 0.3290
# Epoch 4/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7552 - mse: 3.7552 - mae: 1.3286 - mape: 3.4642 - rmse: 1.9227 - ar: 0.9090 - val_loss: 5.1938 - val_mse: 5.1938 - val_mae: 1.6877 - val_mape: 1.0198 - val_rmse: 2.2713 - val_ar: 0.3290
# Epoch 5/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6258 - mse: 3.6258 - mae: 1.3146 - mape: 4.0031 - rmse: 1.8892 - ar: 0.9065 - val_loss: 5.1908 - val_mse: 5.1908 - val_mae: 1.6871 - val_mape: 1.0227 - val_rmse: 2.2706 - val_ar: 0.3290
# Epoch 6/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4370 - mse: 3.4370 - mae: 1.2687 - mape: 2.6875 - rmse: 1.8396 - ar: 0.9036 - val_loss: 5.1873 - val_mse: 5.1873 - val_mae: 1.6864 - val_mape: 1.0266 - val_rmse: 2.2697 - val_ar: 0.3280
# Epoch 7/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8112 - mse: 3.8112 - mae: 1.3291 - mape: 2.3578 - rmse: 1.9376 - ar: 0.9127 - val_loss: 5.1803 - val_mse: 5.1803 - val_mae: 1.6850 - val_mape: 1.0386 - val_rmse: 2.2680 - val_ar: 0.3280
# Epoch 8/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7037 - mse: 3.7037 - mae: 1.3085 - mape: 2.9013 - rmse: 1.9094 - ar: 0.9161 - val_loss: 5.1516 - val_mse: 5.1516 - val_mae: 1.6776 - val_mape: 1.0440 - val_rmse: 2.2614 - val_ar: 0.3158
# Epoch 9/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7146 - mse: 3.7146 - mae: 1.3223 - mape: 3.9270 - rmse: 1.9106 - ar: 0.9199 - val_loss: 5.1190 - val_mse: 5.1190 - val_mae: 1.6694 - val_mape: 1.0483 - val_rmse: 2.2540 - val_ar: 0.3158
# Epoch 10/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4007 - mse: 3.4007 - mae: 1.2697 - mape: 4.1001 - rmse: 1.8335 - ar: 0.9244 - val_loss: 5.0061 - val_mse: 5.0061 - val_mae: 1.6397 - val_mape: 1.0421 - val_rmse: 2.2282 - val_ar: 0.3158
# Epoch 11/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5939 - mse: 3.5939 - mae: 1.3065 - mape: 3.4872 - rmse: 1.8805 - ar: 0.9168 - val_loss: 4.8760 - val_mse: 4.8760 - val_mae: 1.6036 - val_mape: 1.0505 - val_rmse: 2.1979 - val_ar: 0.3169
# Epoch 12/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.9447 - mse: 3.9447 - mae: 1.3190 - mape: 4.4466 - rmse: 1.9679 - ar: 0.9333 - val_loss: 4.9129 - val_mse: 4.9129 - val_mae: 1.6137 - val_mape: 1.0758 - val_rmse: 2.2060 - val_ar: 0.3098
# Epoch 13/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5569 - mse: 3.5569 - mae: 1.3085 - mape: 2.6884 - rmse: 1.8696 - ar: 0.8776 - val_loss: 4.7417 - val_mse: 4.7417 - val_mae: 1.5656 - val_mape: 1.0851 - val_rmse: 2.1656 - val_ar: 0.3107
# Epoch 14/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4947 - mse: 3.4947 - mae: 1.2712 - mape: 1.8955 - rmse: 1.8536 - ar: 0.8883 - val_loss: 4.5801 - val_mse: 4.5801 - val_mae: 1.5169 - val_mape: 1.1090 - val_rmse: 2.1262 - val_ar: 0.3225
# Epoch 15/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8098 - mse: 3.8098 - mae: 1.3194 - mape: 3.5313 - rmse: 1.9271 - ar: 0.9266 - val_loss: 4.4144 - val_mse: 4.4144 - val_mae: 1.4586 - val_mape: 1.1599 - val_rmse: 2.0848 - val_ar: 0.3301
# Epoch 16/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7454 - mse: 3.7454 - mae: 1.3237 - mape: 3.0300 - rmse: 1.9216 - ar: 0.9278 - val_loss: 4.3885 - val_mse: 4.3885 - val_mae: 1.4543 - val_mape: 1.2006 - val_rmse: 2.0776 - val_ar: 0.3399
# Epoch 17/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6949 - mse: 3.6949 - mae: 1.3054 - mape: 3.1874 - rmse: 1.9101 - ar: 0.9127 - val_loss: 4.2213 - val_mse: 4.2213 - val_mae: 1.3964 - val_mape: 1.2335 - val_rmse: 2.0346 - val_ar: 0.3469
# Epoch 18/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6376 - mse: 3.6376 - mae: 1.3087 - mape: 2.4787 - rmse: 1.8928 - ar: 0.9128 - val_loss: 4.1239 - val_mse: 4.1239 - val_mae: 1.3608 - val_mape: 1.2879 - val_rmse: 2.0098 - val_ar: 0.3564
# Epoch 19/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.2756 - mse: 3.2756 - mae: 1.2528 - mape: 2.8109 - rmse: 1.8001 - ar: 0.9170 - val_loss: 4.1483 - val_mse: 4.1483 - val_mae: 1.3731 - val_mape: 1.2893 - val_rmse: 2.0151 - val_ar: 0.3466
# Epoch 20/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4765 - mse: 3.4765 - mae: 1.2759 - mape: 2.9299 - rmse: 1.8491 - ar: 0.9205 - val_loss: 4.0810 - val_mse: 4.0810 - val_mae: 1.3468 - val_mape: 1.4198 - val_rmse: 1.9947 - val_ar: 0.3485
# Epoch 21/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5470 - mse: 3.5470 - mae: 1.2951 - mape: 2.3426 - rmse: 1.8704 - ar: 0.9462 - val_loss: 4.0214 - val_mse: 4.0214 - val_mae: 1.3236 - val_mape: 1.4822 - val_rmse: 1.9786 - val_ar: 0.3498
# Epoch 22/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4224 - mse: 3.4224 - mae: 1.2838 - mape: 6.0982 - rmse: 1.8372 - ar: 0.8867 - val_loss: 4.0484 - val_mse: 4.0484 - val_mae: 1.3254 - val_mape: 1.4481 - val_rmse: 1.9852 - val_ar: 0.3562
# Epoch 23/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5038 - mse: 3.5038 - mae: 1.2877 - mape: 3.5301 - rmse: 1.8601 - ar: 0.9295 - val_loss: 3.8987 - val_mse: 3.8987 - val_mae: 1.2660 - val_mape: 1.5434 - val_rmse: 1.9446 - val_ar: 0.3504
# Epoch 24/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5540 - mse: 3.5540 - mae: 1.2817 - mape: 3.5951 - rmse: 1.8645 - ar: 0.8902 - val_loss: 4.0020 - val_mse: 4.0020 - val_mae: 1.3031 - val_mape: 1.5404 - val_rmse: 1.9716 - val_ar: 0.3639
# Epoch 25/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6133 - mse: 3.6133 - mae: 1.2899 - mape: 2.0705 - rmse: 1.8801 - ar: 0.9427 - val_loss: 3.8939 - val_mse: 3.8939 - val_mae: 1.2536 - val_mape: 1.6238 - val_rmse: 1.9412 - val_ar: 0.3612
# Epoch 26/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7709 - mse: 3.7709 - mae: 1.2977 - mape: 4.2246 - rmse: 1.9156 - ar: 0.9152 - val_loss: 3.8692 - val_mse: 3.8692 - val_mae: 1.2495 - val_mape: 1.5976 - val_rmse: 1.9359 - val_ar: 0.3712
# Epoch 27/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5139 - mse: 3.5139 - mae: 1.2702 - mape: 2.6636 - rmse: 1.8608 - ar: 0.9356 - val_loss: 3.8845 - val_mse: 3.8845 - val_mae: 1.2533 - val_mape: 1.5400 - val_rmse: 1.9412 - val_ar: 0.3672
# Epoch 28/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4418 - mse: 3.4418 - mae: 1.2583 - mape: 2.6566 - rmse: 1.8432 - ar: 0.8937 - val_loss: 3.8914 - val_mse: 3.8914 - val_mae: 1.2522 - val_mape: 1.6787 - val_rmse: 1.9404 - val_ar: 0.3497
# Epoch 29/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.3424 - mse: 3.3424 - mae: 1.2734 - mape: 2.9814 - rmse: 1.8135 - ar: 0.9133 - val_loss: 3.8831 - val_mse: 3.8831 - val_mae: 1.2527 - val_mape: 1.7004 - val_rmse: 1.9392 - val_ar: 0.3390
# Epoch 30/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.3429 - mse: 3.3429 - mae: 1.2378 - mape: 2.4517 - rmse: 1.8115 - ar: 0.9085 - val_loss: 3.9141 - val_mse: 3.9141 - val_mae: 1.2661 - val_mape: 1.6420 - val_rmse: 1.9465 - val_ar: 0.3714
# Epoch 31/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4959 - mse: 3.4959 - mae: 1.2746 - mape: 2.6757 - rmse: 1.8545 - ar: 0.9190 - val_loss: 3.8676 - val_mse: 3.8676 - val_mae: 1.2509 - val_mape: 1.5952 - val_rmse: 1.9346 - val_ar: 0.3717
# Epoch 32/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6286 - mse: 3.6286 - mae: 1.2899 - mape: 3.2150 - rmse: 1.8883 - ar: 0.9001 - val_loss: 3.9591 - val_mse: 3.9591 - val_mae: 1.2856 - val_mape: 1.5065 - val_rmse: 1.9593 - val_ar: 0.3391
# Epoch 33/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4671 - mse: 3.4671 - mae: 1.2821 - mape: 2.8343 - rmse: 1.8507 - ar: 0.9346 - val_loss: 3.9220 - val_mse: 3.9220 - val_mae: 1.2636 - val_mape: 1.6336 - val_rmse: 1.9481 - val_ar: 0.3603
# Epoch 34/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5821 - mse: 3.5821 - mae: 1.2878 - mape: 2.9046 - rmse: 1.8797 - ar: 0.8926 - val_loss: 3.8907 - val_mse: 3.8907 - val_mae: 1.2513 - val_mape: 1.6424 - val_rmse: 1.9407 - val_ar: 0.3577
# Epoch 35/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4788 - mse: 3.4788 - mae: 1.2804 - mape: 3.8204 - rmse: 1.8548 - ar: 0.9265 - val_loss: 3.8921 - val_mse: 3.8921 - val_mae: 1.2571 - val_mape: 1.6056 - val_rmse: 1.9419 - val_ar: 0.3737
# Epoch 36/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5520 - mse: 3.5520 - mae: 1.2931 - mape: 3.0903 - rmse: 1.8624 - ar: 0.9280 - val_loss: 3.8629 - val_mse: 3.8629 - val_mae: 1.2491 - val_mape: 1.8187 - val_rmse: 1.9301 - val_ar: 0.3636
# Epoch 37/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7965 - mse: 3.7965 - mae: 1.3115 - mape: 2.8144 - rmse: 1.9352 - ar: 0.9418 - val_loss: 3.9110 - val_mse: 3.9110 - val_mae: 1.2589 - val_mape: 1.5956 - val_rmse: 1.9440 - val_ar: 0.3340
# Epoch 38/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5213 - mse: 3.5213 - mae: 1.2908 - mape: 4.1980 - rmse: 1.8596 - ar: 0.8771 - val_loss: 3.8535 - val_mse: 3.8535 - val_mae: 1.2424 - val_mape: 1.7872 - val_rmse: 1.9276 - val_ar: 0.3853
# Epoch 39/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5804 - mse: 3.5804 - mae: 1.2709 - mape: 2.4552 - rmse: 1.8738 - ar: 0.9236 - val_loss: 3.8826 - val_mse: 3.8826 - val_mae: 1.2563 - val_mape: 1.5825 - val_rmse: 1.9383 - val_ar: 0.3764
# Epoch 40/100
# 36/36 [==============================] - 1s 19ms/step - loss: 3.6677 - mse: 3.6677 - mae: 1.3129 - mape: 3.0653 - rmse: 1.9028 - ar: 0.9290 - val_loss: 3.8875 - val_mse: 3.8875 - val_mae: 1.2593 - val_mape: 1.5387 - val_rmse: 1.9395 - val_ar: 0.3641
# Epoch 41/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8568 - mse: 3.8568 - mae: 1.3056 - mape: 2.3093 - rmse: 1.9432 - ar: 0.9308 - val_loss: 3.9223 - val_mse: 3.9223 - val_mae: 1.2843 - val_mape: 1.4631 - val_rmse: 1.9495 - val_ar: 0.3529
# Epoch 42/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8534 - mse: 3.8534 - mae: 1.3205 - mape: 3.2552 - rmse: 1.9392 - ar: 0.9416 - val_loss: 3.8830 - val_mse: 3.8830 - val_mae: 1.2542 - val_mape: 1.6167 - val_rmse: 1.9372 - val_ar: 0.3733
# Epoch 43/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.4133 - mse: 3.4133 - mae: 1.2798 - mape: 4.4231 - rmse: 1.8348 - ar: 0.9299 - val_loss: 3.9165 - val_mse: 3.9165 - val_mae: 1.2563 - val_mape: 1.5608 - val_rmse: 1.9465 - val_ar: 0.3684
# [MSE Baseline] train: 3.2635512043345396  test: 3.8851370430342302
# 4/4 [==============================] - 0s 3ms/step - loss: 3.9165 - mse: 3.9165 - mae: 1.2563 - mape: 1.5608 - rmse: 1.9465 - ar: 0.3684

# %% [markdown]
# ## SSE

# %%
data_name = data_names[1]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)

# we drop a couple of years because they have some periods were volume is zero
# we also drop some data which contain nans
dataframe = pd.read_csv(data_path)[1768:].dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

lstm = make_LSTM_model()
history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], lstm)
print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
results[1] = lstm.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/SSE.csv
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 5, 10)             720
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 5, 10)             40
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 5, 10)             0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 10)             0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 10)                840
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 10)                40
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 10)                0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 1,651
# Trainable params: 1,611
# Non-trainable params: 40
# _________________________________________________________________
# Epoch 1/100
# 23/23 [==============================] - 1s 22ms/step - loss: 4.5304 - mse: 4.5304 - mae: 1.5239 - mape: 1.8072 - rmse: 2.1111 - ar: 0.8794 - val_loss: 4.8849 - val_mse: 4.8849 - val_mae: 1.6723 - val_mape: 1.0148 - val_rmse: 2.2082 - val_ar: 0.2980
# Epoch 2/100
# 23/23 [==============================] - 0s 8ms/step - loss: 5.2220 - mse: 5.2220 - mae: 1.4742 - mape: 2.3392 - rmse: 2.2334 - ar: 0.9574 - val_loss: 4.8834 - val_mse: 4.8834 - val_mae: 1.6719 - val_mape: 1.0353 - val_rmse: 2.2079 - val_ar: 0.2980
# Epoch 3/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.8004 - mse: 4.8004 - mae: 1.4297 - mape: 1.4707 - rmse: 2.1523 - ar: 0.9763 - val_loss: 4.8753 - val_mse: 4.8753 - val_mae: 1.6692 - val_mape: 1.2508 - val_rmse: 2.2061 - val_ar: 0.2980
# Epoch 4/100
# 23/23 [==============================] - 0s 8ms/step - loss: 5.2712 - mse: 5.2712 - mae: 1.4077 - mape: 3.9996 - rmse: 2.2304 - ar: 0.9138 - val_loss: 4.8705 - val_mse: 4.8705 - val_mae: 1.6677 - val_mape: 1.3449 - val_rmse: 2.2050 - val_ar: 0.3011
# Epoch 5/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.8393 - mse: 4.8393 - mae: 1.4049 - mape: 1.6105 - rmse: 2.1439 - ar: 0.9599 - val_loss: 4.8666 - val_mse: 4.8666 - val_mae: 1.6664 - val_mape: 1.4578 - val_rmse: 2.2042 - val_ar: 0.2862
# Epoch 6/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.6276 - mse: 4.6276 - mae: 1.3857 - mape: 3.5483 - rmse: 2.0943 - ar: 0.9557 - val_loss: 4.8599 - val_mse: 4.8599 - val_mae: 1.6646 - val_mape: 1.4889 - val_rmse: 2.2027 - val_ar: 0.2862
# Epoch 7/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.9865 - mse: 4.9865 - mae: 1.4433 - mape: 1.5273 - rmse: 2.1926 - ar: 1.0014 - val_loss: 4.8497 - val_mse: 4.8497 - val_mae: 1.6613 - val_mape: 1.6980 - val_rmse: 2.2004 - val_ar: 0.2862
# Epoch 8/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.5654 - mse: 4.5654 - mae: 1.3559 - mape: 2.0804 - rmse: 2.0697 - ar: 0.9598 - val_loss: 4.8411 - val_mse: 4.8411 - val_mae: 1.6588 - val_mape: 1.7678 - val_rmse: 2.1985 - val_ar: 0.2930
# Epoch 9/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.9319 - mse: 4.9319 - mae: 1.3618 - mape: 3.2469 - rmse: 2.1514 - ar: 0.9677 - val_loss: 4.8353 - val_mse: 4.8353 - val_mae: 1.6573 - val_mape: 1.6521 - val_rmse: 2.1972 - val_ar: 0.2930
# Epoch 10/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.8796 - mse: 4.8796 - mae: 1.3890 - mape: 2.5607 - rmse: 2.1659 - ar: 0.9682 - val_loss: 4.8198 - val_mse: 4.8198 - val_mae: 1.6530 - val_mape: 1.7482 - val_rmse: 2.1937 - val_ar: 0.3092
# Epoch 11/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.2762 - mse: 4.2762 - mae: 1.3314 - mape: 2.3146 - rmse: 2.0505 - ar: 0.9661 - val_loss: 4.7962 - val_mse: 4.7962 - val_mae: 1.6469 - val_mape: 1.8676 - val_rmse: 2.1884 - val_ar: 0.3092
# Epoch 12/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.8862 - mse: 4.8862 - mae: 1.3546 - mape: 3.8361 - rmse: 2.1485 - ar: 0.9605 - val_loss: 4.7774 - val_mse: 4.7774 - val_mae: 1.6421 - val_mape: 2.0496 - val_rmse: 2.1841 - val_ar: 0.2899
# Epoch 13/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.7600 - mse: 4.7600 - mae: 1.3600 - mape: 1.6093 - rmse: 2.1443 - ar: 0.9857 - val_loss: 4.7551 - val_mse: 4.7551 - val_mae: 1.6365 - val_mape: 2.1349 - val_rmse: 2.1791 - val_ar: 0.2952
# Epoch 14/100
# 23/23 [==============================] - 0s 9ms/step - loss: 5.1490 - mse: 5.1490 - mae: 1.3777 - mape: 2.4310 - rmse: 2.2123 - ar: 0.9893 - val_loss: 4.7355 - val_mse: 4.7355 - val_mae: 1.6316 - val_mape: 1.9806 - val_rmse: 2.1746 - val_ar: 0.2952
# Epoch 15/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.4368 - mse: 4.4368 - mae: 1.3756 - mape: 4.6942 - rmse: 2.0881 - ar: 1.0182 - val_loss: 4.6993 - val_mse: 4.6993 - val_mae: 1.6225 - val_mape: 1.8828 - val_rmse: 2.1663 - val_ar: 0.2952
# Epoch 16/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.5491 - mse: 4.5491 - mae: 1.3295 - mape: 1.7930 - rmse: 2.0923 - ar: 0.9851 - val_loss: 4.6702 - val_mse: 4.6702 - val_mae: 1.6145 - val_mape: 2.0216 - val_rmse: 2.1597 - val_ar: 0.2963
# Epoch 17/100
# 23/23 [==============================] - 0s 9ms/step - loss: 3.7962 - mse: 3.7962 - mae: 1.2875 - mape: 5.6302 - rmse: 1.9335 - ar: 0.9267 - val_loss: 4.6024 - val_mse: 4.6024 - val_mae: 1.5972 - val_mape: 1.7892 - val_rmse: 2.1440 - val_ar: 0.2963
# Epoch 18/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.2536 - mse: 4.2536 - mae: 1.3297 - mape: 3.7305 - rmse: 2.0363 - ar: 0.9769 - val_loss: 4.5627 - val_mse: 4.5627 - val_mae: 1.5866 - val_mape: 1.3677 - val_rmse: 2.1347 - val_ar: 0.3111
# Epoch 19/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.2369 - mse: 4.2369 - mae: 1.3381 - mape: 4.5974 - rmse: 2.0405 - ar: 0.9888 - val_loss: 4.5139 - val_mse: 4.5139 - val_mae: 1.5750 - val_mape: 2.7816 - val_rmse: 2.1233 - val_ar: 0.3111
# Epoch 20/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.8512 - mse: 4.8512 - mae: 1.3617 - mape: 4.1435 - rmse: 2.1410 - ar: 1.0259 - val_loss: 4.4238 - val_mse: 4.4238 - val_mae: 1.5520 - val_mape: 3.9721 - val_rmse: 2.1020 - val_ar: 0.3111
# Epoch 21/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.1120 - mse: 4.1120 - mae: 1.3087 - mape: 7.2315 - rmse: 2.0001 - ar: 0.9626 - val_loss: 4.3575 - val_mse: 4.3575 - val_mae: 1.5352 - val_mape: 5.8790 - val_rmse: 2.0862 - val_ar: 0.3487
# Epoch 22/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.2397 - mse: 4.2397 - mae: 1.3214 - mape: 1.7434 - rmse: 2.0316 - ar: 1.0241 - val_loss: 4.2479 - val_mse: 4.2479 - val_mae: 1.5059 - val_mape: 5.3533 - val_rmse: 2.0598 - val_ar: 0.3228
# Epoch 23/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.3237 - mse: 4.3237 - mae: 1.3157 - mape: 2.5978 - rmse: 2.0192 - ar: 0.9748 - val_loss: 4.1034 - val_mse: 4.1034 - val_mae: 1.4680 - val_mape: 9.5569 - val_rmse: 2.0244 - val_ar: 0.3725
# Epoch 24/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.5723 - mse: 4.5723 - mae: 1.3391 - mape: 3.6750 - rmse: 2.0885 - ar: 0.9612 - val_loss: 4.0576 - val_mse: 4.0576 - val_mae: 1.4540 - val_mape: 10.2984 - val_rmse: 2.0133 - val_ar: 0.3758
# Epoch 25/100
# 23/23 [==============================] - 0s 9ms/step - loss: 3.9632 - mse: 3.9632 - mae: 1.2848 - mape: 4.3082 - rmse: 1.9532 - ar: 0.9545 - val_loss: 3.9136 - val_mse: 3.9136 - val_mae: 1.4050 - val_mape: 7.9523 - val_rmse: 1.9770 - val_ar: 0.3191
# Epoch 26/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.0544 - mse: 4.0544 - mae: 1.3502 - mape: 4.5654 - rmse: 1.9879 - ar: 1.0047 - val_loss: 3.8191 - val_mse: 3.8191 - val_mae: 1.3756 - val_mape: 9.2753 - val_rmse: 1.9530 - val_ar: 0.3479
# Epoch 27/100
# 23/23 [==============================] - 0s 9ms/step - loss: 3.7678 - mse: 3.7678 - mae: 1.2633 - mape: 6.6281 - rmse: 1.9109 - ar: 0.9845 - val_loss: 3.8592 - val_mse: 3.8592 - val_mae: 1.3957 - val_mape: 16.5098 - val_rmse: 1.9633 - val_ar: 0.3761
# Epoch 28/100
# 23/23 [==============================] - 0s 8ms/step - loss: 3.8204 - mse: 3.8204 - mae: 1.3115 - mape: 5.3551 - rmse: 1.9373 - ar: 1.0182 - val_loss: 3.7352 - val_mse: 3.7352 - val_mae: 1.3506 - val_mape: 13.5715 - val_rmse: 1.9315 - val_ar: 0.3829
# Epoch 29/100
# 23/23 [==============================] - 0s 9ms/step - loss: 3.8831 - mse: 3.8831 - mae: 1.2888 - mape: 3.4313 - rmse: 1.9333 - ar: 0.9708 - val_loss: 3.6830 - val_mse: 3.6830 - val_mae: 1.3342 - val_mape: 14.6068 - val_rmse: 1.9179 - val_ar: 0.3691
# Epoch 30/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.6778 - mse: 4.6778 - mae: 1.3410 - mape: 7.6285 - rmse: 2.1250 - ar: 1.0379 - val_loss: 3.6640 - val_mse: 3.6640 - val_mae: 1.3261 - val_mape: 16.7226 - val_rmse: 1.9129 - val_ar: 0.3822
# Epoch 31/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.2767 - mse: 4.2767 - mae: 1.2797 - mape: 4.2729 - rmse: 2.0058 - ar: 0.9674 - val_loss: 3.6218 - val_mse: 3.6218 - val_mae: 1.3158 - val_mape: 18.7687 - val_rmse: 1.9017 - val_ar: 0.3593
# Epoch 32/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.3564 - mse: 4.3564 - mae: 1.3319 - mape: 4.3345 - rmse: 2.0446 - ar: 0.9903 - val_loss: 3.6020 - val_mse: 3.6020 - val_mae: 1.3065 - val_mape: 22.0911 - val_rmse: 1.8965 - val_ar: 0.3529
# Epoch 33/100
# 23/23 [==============================] - 0s 9ms/step - loss: 3.9566 - mse: 3.9566 - mae: 1.2881 - mape: 2.3866 - rmse: 1.9589 - ar: 0.9809 - val_loss: 3.5326 - val_mse: 3.5326 - val_mae: 1.2842 - val_mape: 22.9995 - val_rmse: 1.8780 - val_ar: 0.3709
# Epoch 34/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.3872 - mse: 4.3872 - mae: 1.2898 - mape: 1.6947 - rmse: 2.0253 - ar: 0.9837 - val_loss: 3.6112 - val_mse: 3.6112 - val_mae: 1.3046 - val_mape: 28.4579 - val_rmse: 1.8990 - val_ar: 0.3222
# Epoch 35/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.5542 - mse: 4.5542 - mae: 1.3907 - mape: 3.7134 - rmse: 2.1092 - ar: 1.0283 - val_loss: 3.4736 - val_mse: 3.4736 - val_mae: 1.2657 - val_mape: 27.4851 - val_rmse: 1.8625 - val_ar: 0.3840
# Epoch 36/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.7008 - mse: 4.7008 - mae: 1.3013 - mape: 2.9782 - rmse: 2.1082 - ar: 0.9976 - val_loss: 3.6381 - val_mse: 3.6381 - val_mae: 1.3040 - val_mape: 34.5258 - val_rmse: 1.9065 - val_ar: 0.3152
# Epoch 37/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.0018 - mse: 4.0018 - mae: 1.3140 - mape: 2.2054 - rmse: 1.9844 - ar: 0.9648 - val_loss: 3.5150 - val_mse: 3.5150 - val_mae: 1.2794 - val_mape: 20.8527 - val_rmse: 1.8735 - val_ar: 0.3701
# Epoch 38/100
# 23/23 [==============================] - 0s 8ms/step - loss: 3.9211 - mse: 3.9211 - mae: 1.3233 - mape: 1.6945 - rmse: 1.9627 - ar: 0.9850 - val_loss: 3.4469 - val_mse: 3.4469 - val_mae: 1.2634 - val_mape: 27.2014 - val_rmse: 1.8555 - val_ar: 0.3955
# Epoch 39/100
# 23/23 [==============================] - 0s 9ms/step - loss: 3.9369 - mse: 3.9369 - mae: 1.3301 - mape: 6.2798 - rmse: 1.9668 - ar: 1.0298 - val_loss: 3.4650 - val_mse: 3.4650 - val_mae: 1.2685 - val_mape: 27.7089 - val_rmse: 1.8604 - val_ar: 0.4000
# Epoch 40/100
# 23/23 [==============================] - 0s 8ms/step - loss: 3.9974 - mse: 3.9974 - mae: 1.3027 - mape: 7.8689 - rmse: 1.9703 - ar: 0.9632 - val_loss: 3.5396 - val_mse: 3.5396 - val_mae: 1.2801 - val_mape: 26.6023 - val_rmse: 1.8803 - val_ar: 0.3462
# Epoch 41/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.7316 - mse: 4.7316 - mae: 1.3384 - mape: 6.1139 - rmse: 2.1276 - ar: 1.0401 - val_loss: 3.6888 - val_mse: 3.6888 - val_mae: 1.3039 - val_mape: 37.1373 - val_rmse: 1.9203 - val_ar: 0.3108
# Epoch 42/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.5560 - mse: 4.5560 - mae: 1.3365 - mape: 4.4538 - rmse: 2.0769 - ar: 0.9695 - val_loss: 3.5028 - val_mse: 3.5028 - val_mae: 1.2812 - val_mape: 28.1190 - val_rmse: 1.8708 - val_ar: 0.3306
# Epoch 43/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.2854 - mse: 4.2854 - mae: 1.3140 - mape: 2.1915 - rmse: 2.0274 - ar: 0.9992 - val_loss: 3.4721 - val_mse: 3.4721 - val_mae: 1.2700 - val_mape: 27.7469 - val_rmse: 1.8629 - val_ar: 0.3631
# [MSE Baseline] train: 4.320522629856832  test: 3.456689356602112
# 3/3 [==============================] - 0s 3ms/step - loss: 3.4721 - mse: 3.4721 - mae: 1.2700 - mape: 27.7469 - rmse: 1.8629 - ar: 0.3631

# %% [markdown]
# ## IBM

# %%
data_name = data_names[2]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

lstm = make_LSTM_model()
history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], lstm)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[2] = lstm.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/IBM.csv
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 5, 10)             720
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5, 10)             40
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 5, 10)             0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 5, 10)             0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 10)                840
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 10)                40
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 10)                0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 1,651
# Trainable params: 1,611
# Non-trainable params: 40
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 17ms/step - loss: 5.6039 - mse: 5.6039 - mae: 1.5154 - mape: 1806.8307 - rmse: 2.2523 - ar: 0.8691 - val_loss: 8.1680 - val_mse: 8.1680 - val_mae: 1.7473 - val_mape: 1.0025 - val_rmse: 2.7575 - val_ar: 0.4084
# Epoch 2/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.6579 - mse: 5.6579 - mae: 1.4489 - mape: inf - rmse: 2.2296 - ar: 0.9197 - val_loss: 8.1622 - val_mse: 8.1622 - val_mae: 1.7457 - val_mape: 1.0035 - val_rmse: 2.7563 - val_ar: 0.4084
# Epoch 3/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.1434 - mse: 5.1434 - mae: 1.3989 - mape: inf - rmse: 2.1595 - ar: 0.8994 - val_loss: 8.1528 - val_mse: 8.1528 - val_mae: 1.7430 - val_mape: 1.0099 - val_rmse: 2.7542 - val_ar: 0.4050
# Epoch 4/100
# 36/36 [==============================] - 0s 8ms/step - loss: 6.1198 - mse: 6.1198 - mae: 1.4425 - mape: inf - rmse: 2.2761 - ar: 0.9604 - val_loss: 8.1389 - val_mse: 8.1389 - val_mae: 1.7389 - val_mape: 1.0170 - val_rmse: 2.7512 - val_ar: 0.3996
# Epoch 5/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.2991 - mse: 5.2991 - mae: 1.4183 - mape: 1046.2413 - rmse: 2.2037 - ar: 0.9605 - val_loss: 8.1221 - val_mse: 8.1221 - val_mae: 1.7340 - val_mape: 1.0291 - val_rmse: 2.7476 - val_ar: 0.4050
# Epoch 6/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.1745 - mse: 4.1745 - mae: 1.3368 - mape: inf - rmse: 1.9833 - ar: 0.9237 - val_loss: 8.0996 - val_mse: 8.0996 - val_mae: 1.7270 - val_mape: 1.0366 - val_rmse: 2.7429 - val_ar: 0.4050
# Epoch 7/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.5562 - mse: 4.5562 - mae: 1.3731 - mape: 1700.1395 - rmse: 2.0672 - ar: 0.9369 - val_loss: 8.0781 - val_mse: 8.0781 - val_mae: 1.7201 - val_mape: 1.0558 - val_rmse: 2.7382 - val_ar: 0.4089
# Epoch 8/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.9955 - mse: 4.9955 - mae: 1.4019 - mape: 4.4287 - rmse: 2.1353 - ar: 0.9567 - val_loss: 8.0482 - val_mse: 8.0482 - val_mae: 1.7115 - val_mape: 1.0570 - val_rmse: 2.7322 - val_ar: 0.4130
# Epoch 9/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.8739 - mse: 4.8739 - mae: 1.3631 - mape: 2.2660 - rmse: 2.1127 - ar: 0.9498 - val_loss: 8.0135 - val_mse: 8.0135 - val_mae: 1.7007 - val_mape: 1.0830 - val_rmse: 2.7248 - val_ar: 0.4133
# Epoch 10/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.6555 - mse: 4.6555 - mae: 1.3194 - mape: inf - rmse: 2.0614 - ar: 0.9054 - val_loss: 7.9446 - val_mse: 7.9446 - val_mae: 1.6801 - val_mape: 1.0764 - val_rmse: 2.7112 - val_ar: 0.4133
# Epoch 11/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.7044 - mse: 4.7044 - mae: 1.3440 - mape: 781.2366 - rmse: 2.0628 - ar: 0.9280 - val_loss: 7.8782 - val_mse: 7.8782 - val_mae: 1.6562 - val_mape: 1.1050 - val_rmse: 2.6969 - val_ar: 0.4219
# Epoch 12/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.4148 - mse: 5.4148 - mae: 1.3728 - mape: inf - rmse: 2.1842 - ar: 0.9375 - val_loss: 7.7716 - val_mse: 7.7716 - val_mae: 1.6243 - val_mape: 1.1298 - val_rmse: 2.6755 - val_ar: 0.4287
# Epoch 13/100
# 36/36 [==============================] - 0s 8ms/step - loss: 6.3601 - mse: 6.3601 - mae: 1.3969 - mape: inf - rmse: 2.3316 - ar: 0.9569 - val_loss: 7.7096 - val_mse: 7.7096 - val_mae: 1.6048 - val_mape: 1.1500 - val_rmse: 2.6635 - val_ar: 0.4362
# Epoch 14/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6923 - mse: 3.6923 - mae: 1.3055 - mape: inf - rmse: 1.9010 - ar: 0.8929 - val_loss: 7.6022 - val_mse: 7.6022 - val_mae: 1.5580 - val_mape: 1.2190 - val_rmse: 2.6387 - val_ar: 0.4421
# Epoch 15/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.1661 - mse: 5.1661 - mae: 1.3658 - mape: inf - rmse: 2.1595 - ar: 0.9637 - val_loss: 7.4781 - val_mse: 7.4781 - val_mae: 1.4986 - val_mape: 1.3434 - val_rmse: 2.6104 - val_ar: 0.4369
# Epoch 16/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.0023 - mse: 5.0023 - mae: 1.3481 - mape: inf - rmse: 2.1167 - ar: 0.9654 - val_loss: 7.4926 - val_mse: 7.4926 - val_mae: 1.4979 - val_mape: 1.3942 - val_rmse: 2.6118 - val_ar: 0.4362
# Epoch 17/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.4032 - mse: 4.4032 - mae: 1.3374 - mape: inf - rmse: 2.0124 - ar: 0.9461 - val_loss: 7.3445 - val_mse: 7.3445 - val_mae: 1.4394 - val_mape: 1.5162 - val_rmse: 2.5809 - val_ar: 0.4597
# Epoch 18/100
# 36/36 [==============================] - 0s 8ms/step - loss: 6.0022 - mse: 6.0022 - mae: 1.3933 - mape: 1258.0374 - rmse: 2.2940 - ar: 0.9912 - val_loss: 7.3906 - val_mse: 7.3906 - val_mae: 1.4483 - val_mape: 1.5314 - val_rmse: 2.5898 - val_ar: 0.4613
# Epoch 19/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.8687 - mse: 4.8687 - mae: 1.3571 - mape: inf - rmse: 2.0826 - ar: 0.9333 - val_loss: 7.2957 - val_mse: 7.2957 - val_mae: 1.4029 - val_mape: 1.7449 - val_rmse: 2.5685 - val_ar: 0.4764
# Epoch 20/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.4207 - mse: 4.4207 - mae: 1.3354 - mape: 4.8512 - rmse: 2.0284 - ar: 0.9605 - val_loss: 7.2920 - val_mse: 7.2920 - val_mae: 1.4145 - val_mape: 1.6369 - val_rmse: 2.5711 - val_ar: 0.5034
# Epoch 21/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.9351 - mse: 5.9351 - mae: 1.3993 - mape: inf - rmse: 2.3130 - ar: 0.9755 - val_loss: 7.3316 - val_mse: 7.3316 - val_mae: 1.4070 - val_mape: 1.8381 - val_rmse: 2.5763 - val_ar: 0.4733
# Epoch 22/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.0145 - mse: 5.0145 - mae: 1.3095 - mape: inf - rmse: 2.0903 - ar: 0.9231 - val_loss: 7.3045 - val_mse: 7.3045 - val_mae: 1.3987 - val_mape: 1.8255 - val_rmse: 2.5696 - val_ar: 0.4838
# Epoch 23/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.3125 - mse: 5.3125 - mae: 1.3424 - mape: 967.0582 - rmse: 2.1401 - ar: 0.9808 - val_loss: 7.2714 - val_mse: 7.2714 - val_mae: 1.3954 - val_mape: 1.8476 - val_rmse: 2.5640 - val_ar: 0.4910
# Epoch 24/100
# 36/36 [==============================] - 0s 8ms/step - loss: 6.4156 - mse: 6.4156 - mae: 1.3846 - mape: inf - rmse: 2.3512 - ar: 0.9775 - val_loss: 7.2955 - val_mse: 7.2955 - val_mae: 1.3943 - val_mape: 1.8687 - val_rmse: 2.5679 - val_ar: 0.4951
# Epoch 25/100
# 36/36 [==============================] - 0s 8ms/step - loss: 7.6578 - mse: 7.6578 - mae: 1.4158 - mape: 2.3351 - rmse: 2.5220 - ar: 0.9994 - val_loss: 7.2876 - val_mse: 7.2876 - val_mae: 1.3918 - val_mape: 2.0893 - val_rmse: 2.5672 - val_ar: 0.4776
# Epoch 26/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.8023 - mse: 4.8023 - mae: 1.3356 - mape: inf - rmse: 2.0809 - ar: 0.9673 - val_loss: 7.2937 - val_mse: 7.2937 - val_mae: 1.3899 - val_mape: 2.0234 - val_rmse: 2.5664 - val_ar: 0.4699
# Epoch 27/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.9887 - mse: 4.9887 - mae: 1.3530 - mape: inf - rmse: 2.1255 - ar: 0.9777 - val_loss: 7.3223 - val_mse: 7.3223 - val_mae: 1.4019 - val_mape: 1.8020 - val_rmse: 2.5730 - val_ar: 0.4975
# Epoch 28/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7708 - mse: 3.7708 - mae: 1.3090 - mape: 733.9172 - rmse: 1.9241 - ar: 0.9626 - val_loss: 7.3043 - val_mse: 7.3043 - val_mae: 1.3894 - val_mape: 1.9089 - val_rmse: 2.5691 - val_ar: 0.5234
# [MSE Baseline] train: 5.328896393842915  test: 7.163597671973363
# 4/4 [==============================] - 0s 3ms/step - loss: 7.3043 - mse: 7.3043 - mae: 1.3894 - mape: 1.9089 - rmse: 2.5691 - ar: 0.5234

# %% [markdown]
# ## MSFT

# %%
data_name = data_names[3]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

lstm = make_LSTM_model()
history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], lstm)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[3] = lstm.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/MSFT.csv
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 5, 7)]            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 5, 10)             720
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 5, 10)             40
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 5, 10)             0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 5, 10)             0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 10)                840
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 10)                40
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 10)                0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 1,651
# Trainable params: 1,611
# Non-trainable params: 40
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 17ms/step - loss: 5.9981 - mse: 5.9981 - mae: 1.5535 - mape: 11.7283 - rmse: 2.3293 - ar: 0.8878 - val_loss: 12.2135 - val_mse: 12.2135 - val_mae: 1.7454 - val_mape: 0.9982 - val_rmse: 3.0783 - val_ar: 0.3476
# Epoch 2/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.2564 - mse: 5.2564 - mae: 1.4707 - mape: 1.5400 - rmse: 2.2168 - ar: 0.9429 - val_loss: 12.2270 - val_mse: 12.2270 - val_mae: 1.7479 - val_mape: 1.0024 - val_rmse: 3.0802 - val_ar: 0.3465
# Epoch 3/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.2740 - mse: 4.2740 - mae: 1.4071 - mape: 1.5248 - rmse: 2.0560 - ar: 0.9378 - val_loss: 12.2348 - val_mse: 12.2348 - val_mae: 1.7490 - val_mape: 1.0095 - val_rmse: 3.0811 - val_ar: 0.3488
# Epoch 4/100
# 36/36 [==============================] - 0s 8ms/step - loss: 6.0337 - mse: 6.0337 - mae: 1.4178 - mape: 1.7568 - rmse: 2.3193 - ar: 0.9419 - val_loss: 12.2397 - val_mse: 12.2397 - val_mae: 1.7495 - val_mape: 1.0157 - val_rmse: 3.0817 - val_ar: 0.3481
# Epoch 5/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.0749 - mse: 4.0749 - mae: 1.3767 - mape: 10.4921 - rmse: 1.9953 - ar: 0.9243 - val_loss: 12.2391 - val_mse: 12.2391 - val_mae: 1.7488 - val_mape: 1.0213 - val_rmse: 3.0812 - val_ar: 0.3481
# Epoch 6/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.4079 - mse: 5.4079 - mae: 1.4181 - mape: 56.5047 - rmse: 2.2341 - ar: 0.9555 - val_loss: 12.2345 - val_mse: 12.2345 - val_mae: 1.7467 - val_mape: 1.0274 - val_rmse: 3.0799 - val_ar: 0.3481
# [MSE Baseline] train: 4.12855297849621  test: 10.919209093531334
# 4/4 [==============================] - 0s 3ms/step - loss: 12.2345 - mse: 12.2345 - mae: 1.7467 - mape: 1.0274 - rmse: 3.0799 - ar: 0.3481

# %% [markdown]
# ## PAICC

# %%
data_name = data_names[4]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

lstm = make_LSTM_model()
history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], lstm)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[4] = lstm.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/PAICC.csv
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 5, 7)]            0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 5, 10)             720
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 5, 10)             40
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 5, 10)             0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 5, 10)             0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 10)                840
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 10)                40
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 10)                0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 1)                 0
# =================================================================
# Total params: 1,651
# Trainable params: 1,611
# Non-trainable params: 40
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 21ms/step - loss: 4.4804 - mse: 4.4804 - mae: 1.5205 - mape: inf - rmse: 2.0973 - ar: 0.8631 - val_loss: 5.0966 - val_mse: 5.0966 - val_mae: 1.7484 - val_mape: 5.6169 - val_rmse: 2.2575 - val_ar: 0.2460
# Epoch 2/100
# 26/26 [==============================] - 0s 8ms/step - loss: 4.3640 - mse: 4.3640 - mae: 1.4335 - mape: inf - rmse: 2.0706 - ar: 0.9497 - val_loss: 5.0953 - val_mse: 5.0953 - val_mae: 1.7478 - val_mape: 9.2072 - val_rmse: 2.2572 - val_ar: 0.2460
# Epoch 3/100
# 26/26 [==============================] - 0s 8ms/step - loss: 4.0681 - mse: 4.0681 - mae: 1.3950 - mape: inf - rmse: 2.0070 - ar: 0.9623 - val_loss: 5.0938 - val_mse: 5.0938 - val_mae: 1.7472 - val_mape: 13.4104 - val_rmse: 2.2568 - val_ar: 0.2310
# Epoch 4/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.7619 - mse: 3.7619 - mae: 1.3711 - mape: inf - rmse: 1.9292 - ar: 0.9286 - val_loss: 5.0917 - val_mse: 5.0917 - val_mae: 1.7464 - val_mape: 17.9717 - val_rmse: 2.2564 - val_ar: 0.2310
# Epoch 5/100
# 26/26 [==============================] - 0s 8ms/step - loss: 4.0167 - mse: 4.0167 - mae: 1.3883 - mape: inf - rmse: 1.9906 - ar: 1.0011 - val_loss: 5.0900 - val_mse: 5.0900 - val_mae: 1.7457 - val_mape: 21.9610 - val_rmse: 2.2560 - val_ar: 0.2310
# Epoch 6/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.8410 - mse: 3.8410 - mae: 1.3446 - mape: inf - rmse: 1.9471 - ar: 0.9590 - val_loss: 5.0860 - val_mse: 5.0860 - val_mae: 1.7441 - val_mape: 26.5740 - val_rmse: 2.2550 - val_ar: 0.2289
# Epoch 7/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6669 - mse: 3.6669 - mae: 1.3376 - mape: inf - rmse: 1.8991 - ar: 0.9575 - val_loss: 5.0755 - val_mse: 5.0755 - val_mae: 1.7409 - val_mape: 30.6703 - val_rmse: 2.2527 - val_ar: 0.2269
# Epoch 8/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6326 - mse: 3.6326 - mae: 1.3207 - mape: inf - rmse: 1.8894 - ar: 0.9590 - val_loss: 5.0627 - val_mse: 5.0627 - val_mae: 1.7377 - val_mape: 32.4233 - val_rmse: 2.2498 - val_ar: 0.2269
# Epoch 9/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.3764 - mse: 3.3764 - mae: 1.2681 - mape: inf - rmse: 1.8205 - ar: 0.9178 - val_loss: 5.0463 - val_mse: 5.0463 - val_mae: 1.7332 - val_mape: 36.6069 - val_rmse: 2.2462 - val_ar: 0.2201
# Epoch 10/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.5249 - mse: 3.5249 - mae: 1.2771 - mape: inf - rmse: 1.8594 - ar: 0.9422 - val_loss: 5.0240 - val_mse: 5.0240 - val_mae: 1.7275 - val_mape: 37.2761 - val_rmse: 2.2412 - val_ar: 0.2201
# Epoch 11/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.5672 - mse: 3.5672 - mae: 1.3010 - mape: inf - rmse: 1.8792 - ar: 0.9760 - val_loss: 4.9968 - val_mse: 4.9968 - val_mae: 1.7204 - val_mape: 41.1110 - val_rmse: 2.2351 - val_ar: 0.2201
# Epoch 12/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4259 - mse: 3.4259 - mae: 1.2613 - mape: inf - rmse: 1.8349 - ar: 0.9641 - val_loss: 4.9550 - val_mse: 4.9550 - val_mae: 1.7093 - val_mape: 45.0896 - val_rmse: 2.2257 - val_ar: 0.2201
# Epoch 13/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.7907 - mse: 3.7907 - mae: 1.3272 - mape: inf - rmse: 1.9217 - ar: 0.9889 - val_loss: 4.9066 - val_mse: 4.9066 - val_mae: 1.6974 - val_mape: 45.8624 - val_rmse: 2.2148 - val_ar: 0.2269
# Epoch 14/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4687 - mse: 3.4687 - mae: 1.2731 - mape: inf - rmse: 1.8462 - ar: 0.9315 - val_loss: 4.8661 - val_mse: 4.8661 - val_mae: 1.6862 - val_mape: 51.0837 - val_rmse: 2.2056 - val_ar: 0.2277
# Epoch 15/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6458 - mse: 3.6458 - mae: 1.3123 - mape: inf - rmse: 1.8907 - ar: 0.9765 - val_loss: 4.7481 - val_mse: 4.7481 - val_mae: 1.6543 - val_mape: 50.8134 - val_rmse: 2.1786 - val_ar: 0.2344
# Epoch 16/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.5424 - mse: 3.5424 - mae: 1.2846 - mape: inf - rmse: 1.8703 - ar: 0.9468 - val_loss: 4.6649 - val_mse: 4.6649 - val_mae: 1.6334 - val_mape: 55.5984 - val_rmse: 2.1595 - val_ar: 0.2270
# Epoch 17/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.2212 - mse: 3.2212 - mae: 1.2581 - mape: inf - rmse: 1.7855 - ar: 0.9922 - val_loss: 4.5818 - val_mse: 4.5818 - val_mae: 1.6082 - val_mape: 72.6596 - val_rmse: 2.1400 - val_ar: 0.2202
# Epoch 18/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.7225 - mse: 3.7225 - mae: 1.3212 - mape: inf - rmse: 1.9088 - ar: 0.9788 - val_loss: 4.4409 - val_mse: 4.4409 - val_mae: 1.5673 - val_mape: 72.0973 - val_rmse: 2.1069 - val_ar: 0.2269
# Epoch 19/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3808 - mse: 3.3808 - mae: 1.2658 - mape: inf - rmse: 1.8248 - ar: 1.0018 - val_loss: 4.2995 - val_mse: 4.2995 - val_mae: 1.5277 - val_mape: 88.0501 - val_rmse: 2.0730 - val_ar: 0.2197
# Epoch 20/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3968 - mse: 3.3968 - mae: 1.2547 - mape: inf - rmse: 1.8286 - ar: 0.9632 - val_loss: 4.0650 - val_mse: 4.0650 - val_mae: 1.4653 - val_mape: 73.0787 - val_rmse: 2.0160 - val_ar: 0.2337
# Epoch 21/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6822 - mse: 3.6822 - mae: 1.3071 - mape: inf - rmse: 1.9055 - ar: 1.0002 - val_loss: 3.8746 - val_mse: 3.8746 - val_mae: 1.4058 - val_mape: 98.4223 - val_rmse: 1.9680 - val_ar: 0.2533
# Epoch 22/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3035 - mse: 3.3035 - mae: 1.2558 - mape: inf - rmse: 1.8030 - ar: 0.9791 - val_loss: 3.7616 - val_mse: 3.7616 - val_mae: 1.3715 - val_mape: 110.6762 - val_rmse: 1.9388 - val_ar: 0.2677
# Epoch 23/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4623 - mse: 3.4623 - mae: 1.2775 - mape: inf - rmse: 1.8436 - ar: 1.0062 - val_loss: 3.6670 - val_mse: 3.6670 - val_mae: 1.3427 - val_mape: 98.4888 - val_rmse: 1.9145 - val_ar: 0.2589
# Epoch 24/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.5729 - mse: 3.5729 - mae: 1.2859 - mape: inf - rmse: 1.8706 - ar: 0.9653 - val_loss: 3.6649 - val_mse: 3.6649 - val_mae: 1.3368 - val_mape: 94.5293 - val_rmse: 1.9143 - val_ar: 0.2852
# Epoch 25/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.2295 - mse: 3.2295 - mae: 1.2264 - mape: inf - rmse: 1.7762 - ar: 0.9431 - val_loss: 3.5771 - val_mse: 3.5771 - val_mae: 1.3085 - val_mape: 123.1563 - val_rmse: 1.8911 - val_ar: 0.2840
# Epoch 26/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3470 - mse: 3.3470 - mae: 1.2674 - mape: inf - rmse: 1.8155 - ar: 0.9857 - val_loss: 3.4292 - val_mse: 3.4292 - val_mae: 1.2529 - val_mape: 118.2803 - val_rmse: 1.8517 - val_ar: 0.3133
# Epoch 27/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.5616 - mse: 3.5616 - mae: 1.2791 - mape: inf - rmse: 1.8731 - ar: 0.9826 - val_loss: 3.5829 - val_mse: 3.5829 - val_mae: 1.3139 - val_mape: 142.4936 - val_rmse: 1.8926 - val_ar: 0.3076
# Epoch 28/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6154 - mse: 3.6154 - mae: 1.2869 - mape: inf - rmse: 1.8871 - ar: 0.9661 - val_loss: 3.3387 - val_mse: 3.3387 - val_mae: 1.2250 - val_mape: 162.7180 - val_rmse: 1.8269 - val_ar: 0.3253
# Epoch 29/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6156 - mse: 3.6156 - mae: 1.2685 - mape: inf - rmse: 1.8821 - ar: 0.9476 - val_loss: 3.4254 - val_mse: 3.4254 - val_mae: 1.2513 - val_mape: 177.4155 - val_rmse: 1.8505 - val_ar: 0.3094
# Epoch 30/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4453 - mse: 3.4453 - mae: 1.2677 - mape: inf - rmse: 1.8386 - ar: 0.9645 - val_loss: 3.4018 - val_mse: 3.4018 - val_mae: 1.2372 - val_mape: 167.5903 - val_rmse: 1.8441 - val_ar: 0.2841
# Epoch 31/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.9198 - mse: 3.9198 - mae: 1.2954 - mape: inf - rmse: 1.9531 - ar: 1.0054 - val_loss: 3.4071 - val_mse: 3.4071 - val_mae: 1.2462 - val_mape: 129.3891 - val_rmse: 1.8456 - val_ar: 0.2924
# Epoch 32/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4124 - mse: 3.4124 - mae: 1.2740 - mape: inf - rmse: 1.8334 - ar: 0.9810 - val_loss: 3.3712 - val_mse: 3.3712 - val_mae: 1.2396 - val_mape: 145.0890 - val_rmse: 1.8359 - val_ar: 0.3038
# Epoch 33/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.9847 - mse: 3.9847 - mae: 1.3221 - mape: inf - rmse: 1.9687 - ar: 0.9843 - val_loss: 3.4362 - val_mse: 3.4362 - val_mae: 1.2568 - val_mape: 121.7534 - val_rmse: 1.8534 - val_ar: 0.2992
# [MSE Baseline] train: 3.193918730894208  test: 3.2622905110959155
# 3/3 [==============================] - 0s 3ms/step - loss: 3.4362 - mse: 3.4362 - mae: 1.2568 - mape: 121.7534 - rmse: 1.8534 - ar: 0.2992

# %% [markdown]
# ## Results

# %%
df = pd.DataFrame(data = results, index = data_names, columns = metrics)
df.loc['mean'] = results.mean(axis=0)
df
# Out:
#              loss        mse       mae        mape      rmse        ar
# S&P500   3.916466   3.916466  1.256258    1.560831  1.946503  0.368431
# SSE      3.472124   3.472124  1.270031   27.746870  1.862892  0.363135
# IBM      7.304291   7.304291  1.389354    1.908855  2.569130  0.523419
# MSFT    12.234509  12.234509  1.746664    1.027393  3.079903  0.348114
# PAICC    3.436152   3.436152  1.256775  121.753395  1.853421  0.299162
# mean     6.072709   6.072709  1.383816   30.799469  2.262370  0.380452
